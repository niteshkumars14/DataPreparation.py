# %%
# Importing pandas Library.
import os
import pandas as pd
import numpy as np

# %%
# importing csv.
df = pd.read_csv('data.csv')

# %%
# Check Number of columns & Row.
df.shape
# Out:
# (6666, 22)

# %%
# Check Column Names.
df.columns
# Out:
# Index(['Account Length', 'VMail Message', 'Day Mins', 'Eve Mins', 'Night Mins',
#        'Intl Mins', 'CustServ Calls', 'Churn', 'Intl Plan', 'VMail Plan',
#        'Day Calls', 'Day Charge', 'Daily Charges MV', 'Eve Calls',
#        'Eve Charge', 'Night Calls', 'Night Charge', 'Intl Calls',
#        'Intl Charge', 'State', 'Area Code', 'Phone'],
#       dtype='object')

# %%
# Check Datatypes
df.dtypes
# Out:
# Account Length      float64
# VMail Message       float64
# Day Mins            float64
# Eve Mins            float64
# Night Mins          float64
# Intl Mins           float64
# CustServ Calls      float64
# Churn               float64
# Intl Plan           float64
# VMail Plan          float64
# Day Calls           float64
# Day Charge          float64
# Daily Charges MV    float64
# Eve Calls           float64
# Eve Charge          float64
# Night Calls         float64
# Night Charge        float64
# Intl Calls          float64
# Intl Charge         float64
# State                object
# Area Code           float64
# Phone                object
# dtype: object

# %%
# Check first 5 Rows of the Data.
df.head()
# Out:
#    Account Length  VMail Message  Day Mins  Eve Mins  Night Mins  Intl Mins  \
# 0             NaN            NaN       NaN       NaN         NaN        NaN
# 1           128.0           25.0     265.1     197.4       244.7       10.0
# 2             NaN            NaN       NaN       NaN         NaN        NaN
# 3           107.0           26.0     161.6     195.5       254.4       13.7
# 4             NaN            NaN       NaN       NaN         NaN        NaN
#
#    CustServ Calls  Churn  Intl Plan  VMail Plan  ...  Daily Charges MV  \
# 0             NaN    NaN        NaN         NaN  ...               NaN
# 1             1.0    0.0        0.0         1.0  ...             45.07
# 2             NaN    NaN        NaN         NaN  ...               NaN
# 3             1.0    0.0        0.0         1.0  ...             27.47
# 4             NaN    NaN        NaN         NaN  ...               NaN
#
#    Eve Calls  Eve Charge  Night Calls  Night Charge  Intl Calls  Intl Charge  \
# ...

# %%
# Check Last 5 Rows of the Data.
df.head()
# Out:
#    Account Length  VMail Message  Day Mins  Eve Mins  Night Mins  Intl Mins  \
# 0             NaN            NaN       NaN       NaN         NaN        NaN
# 1           128.0           25.0     265.1     197.4       244.7       10.0
# 2             NaN            NaN       NaN       NaN         NaN        NaN
# 3           107.0           26.0     161.6     195.5       254.4       13.7
# 4             NaN            NaN       NaN       NaN         NaN        NaN
#
#    CustServ Calls  Churn  Intl Plan  VMail Plan  ...  Daily Charges MV  \
# 0             NaN    NaN        NaN         NaN  ...               NaN
# 1             1.0    0.0        0.0         1.0  ...             45.07
# 2             NaN    NaN        NaN         NaN  ...               NaN
# 3             1.0    0.0        0.0         1.0  ...             27.47
# 4             NaN    NaN        NaN         NaN  ...               NaN
#
#    Eve Calls  Eve Charge  Night Calls  Night Charge  Intl Calls  Intl Charge  \
# ...

# %%
# Remove Rows where all columns are blank.
df = df.dropna(axis=0, how='all').reset_index(drop=True)

# %%
df.head(4)
# Out:
#    Account Length  VMail Message  Day Mins  Eve Mins  Night Mins  Intl Mins  \
# 0           128.0           25.0     265.1     197.4       244.7       10.0
# 1           107.0           26.0     161.6     195.5       254.4       13.7
# 2           137.0            0.0     243.4     121.2       162.6       12.2
# 3            84.0            0.0     299.4      61.9       196.9        6.6
#
#    CustServ Calls  Churn  Intl Plan  VMail Plan  ...  Daily Charges MV  \
# 0             1.0    0.0        0.0         1.0  ...             45.07
# 1             1.0    0.0        0.0         1.0  ...             27.47
# 2             0.0    0.0        0.0         0.0  ...             41.38
# 3             2.0    0.0        1.0         0.0  ...             50.90
#
#    Eve Calls  Eve Charge  Night Calls  Night Charge  Intl Calls  Intl Charge  \
# 0       99.0       16.78         91.0         11.01         3.0         2.70
# ...

# %%
# Check if the data has duplicates.
# If yes, Remove it.
df = df.drop_duplicates()

# %%
# Check missing Values of each Column.
df.isnull().sum()
# Out:
# Account Length       0
# VMail Message        0
# Day Mins             0
# Eve Mins             0
# Night Mins           0
# Intl Mins            0
# CustServ Calls       0
# Churn                0
# Intl Plan            0
# VMail Plan           0
# Day Calls            0
# Day Charge           0
# Daily Charges MV    50
# Eve Calls            0
# Eve Charge           0
# Night Calls          0
# Night Charge         0
# Intl Calls           0
# Intl Charge          0
# State                0
# Area Code            0
# Phone                0
# dtype: int64

# %%
# Fill Missing Values.
# Missing Values should be filled with a value which satisfy both business & statistical aspects.
# Replacing Null Values with mean.
df['Daily Charges MV'].fillna(df['Daily Charges MV'].mean(), inplace=True)

# %%
# Check missing Values of DataFrame.
df.isnull().sum().sum()
# Out:
# 0

# %%
# Changing Column Datatypes.
# Initially Python read "Area code" columns as "FLOAT" datatype because it contains only Numbers.
# But "Area Code" belongs to a Categorical Column.
# Converting "Area Code" to class 'Object'
df['Area Code'] = df['Area Code'].astype('str')
df['Area Code'].dtype
# Out:
# dtype('O')

# %%
# Check DataFrame Summary.
df.describe()
# Out:
#        Account Length  VMail Message     Day Mins     Eve Mins   Night Mins  \
# count     3333.000000    3333.000000  3333.000000  3333.000000  3333.000000
# mean       101.064806       8.099010   179.775098   200.980348   200.872037
# std         39.822106      13.688365    54.467389    50.713844    50.573847
# min          1.000000       0.000000     0.000000     0.000000    23.200000
# 25%         74.000000       0.000000   143.700000   166.600000   167.000000
# 50%        101.000000       0.000000   179.400000   201.400000   201.200000
# 75%        127.000000      20.000000   216.400000   235.300000   235.300000
# max        243.000000      51.000000   350.800000   363.700000   395.000000
#
#          Intl Mins  CustServ Calls        Churn    Intl Plan   VMail Plan  \
# count  3333.000000     3333.000000  3333.000000  3333.000000  3333.000000
# mean     10.237294        1.562856     0.144914     0.096910     0.276628
# ...

# %%
# Check Correlation.
from matplotlib import pyplot as plt
import seaborn as sns
corr = df.corr()
plt.figure(figsize=(12,8))
sns.heatmap(corr, cmap="Greens",annot=True)

# %% [markdown]
# ### Correlation Matrix can be confusing sometimes, specially when you have more columns.
# ### There is another of checking correlation when you have more columns.

# %%
corr[corr < 1].unstack().transpose()\
    .sort_values( ascending=False)\
    .drop_duplicates()
# Out:
# Day Charge        Day Mins          1.000000
# Eve Charge        Eve Mins          1.000000
# Night Mins        Night Charge      0.999999
# Intl Mins         Intl Charge       0.999993
# Daily Charges MV  Day Mins          0.986693
#                                       ...
# Night Charge      Intl Plan        -0.028913
# Intl Calls        Churn            -0.052844
# Churn             VMail Message    -0.089728
#                   VMail Plan       -0.102148
# Account Length    Account Length         NaN
# Length: 172, dtype: float64

# %% [markdown]
# ###  ---------------------------------------------------------------------------------------------------  ###
